# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets  
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import  DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %%
data = pd.read_csv('D:/study docs/Excel R/Data science/assignment/Decision Tree/Datasets/Fraud_check.csv')

# %%
data.head()
# Out:
#   Undergrad Marital.Status  Taxable.Income  City.Population  Work.Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %%
data=pd.get_dummies(data,columns=['Undergrad','Marital.Status','Urban'])

# %%
data
# Out:
#      Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# 0             68833            50047               10             1
# 1             33700           134075               18             0
# 2             36925           160205               30             1
# 3             50190           193264               15             0
# 4             81002            27533               28             1
# ..              ...              ...              ...           ...
# 595           76340            39492                7             0
# 596           69967            55369                2             0
# 597           47334           154058                0             1
# 598           98592           180083               17             0
# 599           96519           158137               16             1
#
#      Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0                0                        0                       0
# ...

# %%
data["TaxInc"] = pd.cut(data["Taxable.Income"], bins = [10002,30000,99620], labels = ["Risky", "Good"])

# %%
data[data['Taxable.Income'] <=30000]
# Out:
#      Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# 10            29732           102602               19             1
# 12            11794           148033               14             1
# 16            24987            34551               29             0
# 19            10987           126953               30             1
# 21            14310            29106                7             0
# ..              ...              ...              ...           ...
# 544           29916           133877               21             1
# 557           12810           157421               10             0
# 567           16316           129912               30             0
# 575           10735            95975               13             1
# 591           27394           132859               18             0
#
#      Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 10               0                        0                       0
# ...

# %%
data[data['Taxable.Income'] >= 30000]
# Out:
#      Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# 0             68833            50047               10             1
# 1             33700           134075               18             0
# 2             36925           160205               30             1
# 3             50190           193264               15             0
# 4             81002            27533               28             1
# ..              ...              ...              ...           ...
# 595           76340            39492                7             0
# 596           69967            55369                2             0
# 597           47334           154058                0             1
# 598           98592           180083               17             0
# 599           96519           158137               16             1
#
#      Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0                0                        0                       0
# ...

# %%
data
# Out:
#      Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# 0             68833            50047               10             1
# 1             33700           134075               18             0
# 2             36925           160205               30             1
# 3             50190           193264               15             0
# 4             81002            27533               28             1
# ..              ...              ...              ...           ...
# 595           76340            39492                7             0
# 596           69967            55369                2             0
# 597           47334           154058                0             1
# 598           98592           180083               17             0
# 599           96519           158137               16             1
#
#      Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0                0                        0                       0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
data.iloc[:,-1] = labelencoder.fit_transform(data.iloc[:,-1])

# %%
data
# Out:
#      Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# 0             68833            50047               10             1
# 1             33700           134075               18             0
# 2             36925           160205               30             1
# 3             50190           193264               15             0
# 4             81002            27533               28             1
# ..              ...              ...              ...           ...
# 595           76340            39492                7             0
# 596           69967            55369                2             0
# 597           47334           154058                0             1
# 598           98592           180083               17             0
# 599           96519           158137               16             1
#
#      Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0                0                        0                       0
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data.iloc[:,0:3] = scaler.fit_transform(data.iloc[:,0:3])

# %%
data
# Out:
#      Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# 0          0.520362        -1.178521        -0.629143             1
# 1         -0.821464         0.508500         0.276370             0
# 2         -0.698292         1.033109         1.634639             1
# 3         -0.191666         1.696831        -0.063197             0
# 4          0.985129        -1.630532         1.408261             1
# ..              ...              ...              ...           ...
# 595        0.807075        -1.390432        -0.968710             0
# 596        0.563672        -1.071672        -1.534655             0
# 597       -0.300744         0.909696        -1.761033             1
# 598        1.656940         1.432197         0.163181             0
# 599        1.577766         0.991590         0.049992             1
#
#      Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0                0                        0                       0
# ...

# %%
data.dtypes
# Out:
# Taxable.Income             float64
# City.Population            float64
# Work.Experience            float64
# Undergrad_NO                 uint8
# Undergrad_YES                uint8
# Marital.Status_Divorced      uint8
# Marital.Status_Married       uint8
# Marital.Status_Single        uint8
# Urban_NO                     uint8
# Urban_YES                    uint8
# TaxInc                       int32
# dtype: object

# %%
data['TaxInc']=data['TaxInc'].astype('category')

# %%
data.dtypes
# Out:
# Taxable.Income              float64
# City.Population             float64
# Work.Experience             float64
# Undergrad_NO                  uint8
# Undergrad_YES                 uint8
# Marital.Status_Divorced       uint8
# Marital.Status_Married        uint8
# Marital.Status_Single         uint8
# Urban_NO                      uint8
# Urban_YES                     uint8
# TaxInc                     category
# dtype: object

# %%
x = data.iloc[:,:-1]
y = data['TaxInc']

# %%
y.value_counts()
# Out:
# 0    476
# 1    124
# Name: TaxInc, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y ,test_size = 0.2)

# %%
model = DecisionTreeClassifier(criterion = 'entropy',max_depth=3)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
preds = model.predict(x_test)  
pd.Series(preds).value_counts()
# Out:
# 0    97
# 1    23
# dtype: int64

# %%
pd.crosstab(y_test,preds)
# Out:
# col_0    0   1
# TaxInc
# 0       97   1
# 1        0  22
